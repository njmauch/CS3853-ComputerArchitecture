# %% [markdown]
# ##Set Up Files

# %%
#Mount google drive to get files 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Make sure both files are in this location!
# %cd /content/gdrive/My Drive/"Arch Comp Project"
# Out:
# /content/gdrive/My Drive/Arch Comp Project

# %%
#Display files in current directory to check if files exist
# !ls
# Out:
# 2020_02_CS3853_Team_03.ipynb  TestTrace.trc  Trace1.trc
# CacheSim_v2.01.exe.bin	      Test.txt
# comparchproject_main.py       TinyTrace.trc

# %% [markdown]
# ##Run The Program

# %%
#Run the program with the proper command line arugments
# !python3 "comparchproject_main.py" -f trace1.txt -s 1024 -b 16 -a 2 -r RR
# Out:
# ['comparchproject_main.py', '-f', 'trace1.txt', '-s', '1024', '-b', '16', '-a', '2', '-r', 'RR']
# Cache Simulator - CS 3853 - Team 03
#
# Trace File:  trace1.txt
#
# ***** Cache Input Parameters *****
#
# Cache Size:			 1024
# Block Size:			 16
# Associativity:			 2
# Replacement Policy:		 Round Robin
#
# ***** Cache Calculated Values *****
#
# Block count:  65536
# Total # Blocks: 		 65536
# Tag Size: 			 13  bits
# Index Size: 			 15  bits
# Total # Rows:: 			 32768
# Overhead Size: 			 114688.0 Bytes
# Implementation Memory Size: 	 11632  KB	(1163264.0  Bytes)
# Cost: 				 $58.16
